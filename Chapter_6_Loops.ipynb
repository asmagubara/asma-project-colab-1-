# %% [markdown]
# <a href="https://colab.research.google.com/github/asmagubara/asma-project-colab-1-/blob/main/Chapter_6_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1: Pizza Toppings
#
# Write a loop that prompts the user to enter a series of pizza toppings until they enter a 'quit' value. As they enter each topping,
# print a message saying you’ll add that topping to their pizza.

# %%
# ask the user which toppings they want to add in their pizza
prompt = "\nWhat topping would you like to have on your pizza?"
prompt += "\nEnter 'quit' when you are finished: "
# print the output using while function
while True:
    topping = input(prompt)
    if topping != 'quit':
        print("  I'll add " + topping + " to your pizza.")
    else:
        break
# Out:
# What topping would you like to have on your pizza?
# Enter 'quit' when you are finished: extra cheese
#   I'll add extra cheese to your pizza.
#
# What topping would you like to have on your pizza?
# Enter 'quit' when you are finished: pepparoni
#   I'll add pepparoni to your pizza.
#
# What topping would you like to have on your pizza?
# Enter 'quit' when you are finished: quit

# %% [markdown]
# Exercise 2: Movie Tickets
#
# A movie theater charges different ticket prices depending on a person’s age.
#  If a person is under the age of 3, the ticket is free; if
#
# they are between 3 and 12, the ticket is $10; and if they are over age 12, the ticket is $15.
# Write a loop in which you ask users their
#
# age, and then tell them the cost of their movie ticket.

# %%
#ask the user for their age
user = "How old are you?"
user += "\nEnter 'quit' when you are done. "

while True:
    age = input(user)
    if age == 'quit':
        break
    age = int(age)

    if age < 3:
        print("  You get in free!")
    elif age < 13:
        print("  Your ticket is $10.")
    else:
        print("  Your ticket is $15.")
# Out:
# How old are you?
# Enter 'quit' when you are done. 1
#   You get in free!
# How old are you?
# Enter 'quit' when you are done. 3
#   Your ticket is $10.
# How old are you?
# Enter 'quit' when you are done. 9
#   Your ticket is $10.
# How old are you?
# Enter 'quit' when you are done. 15
#   Your ticket is $15.
# How old are you?
# Enter 'quit' when you are done. 12
#   Your ticket is $10.
# How old are you?
# Enter 'quit' when you are done. quit

# %% [markdown]
# Exercise 3: Infinity
#
# Write a loop that never ends, and run it. (To end the loop, press ctrl-C or close the window displaying the output.)

# %%
x=9
while x>0:
  print(x)
  x+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# 21672796
# 21672797
# 21672798
# 21672799
# 21672800
# 21672801
# 21672802
# 21672803
# 21672804
# 21672805
# 21672806
# 21672807
# 21672808
# 21672809
# 21672810
# 21672811
# 21672812
# 21672813
# 21672814
# 21672815
# 21672816
# 21672817
# 21672818
# 21672819
# 21672820
# 21672821
# 21672822
# 21672823
# 21672824
# 21672825
# 21672826
# 21672827
# 21672828
# 21672829
# 21672830
# 21672831
# 21672832
# 21672833
# 21672834
# 21672835
# 21672836
# 21672837
# 21672838
# 21672839
# 21672840
# 21672841
# 21672842
# 21672843
# 21672844
# 21672845
# 21672846
# 21672847
# 21672848
# 21672849
# 21672850
# 21672851
# 21672852
# 21672853
# 21672854
# 21672855
# 21672856
# 21672857
# 21672858
# 21672859
# 21672860
# 21672861
# 21672862
# 21672863
# 21672864
# 21672865
# 21672866
# 21672867
# 21672868
# 21672869
# 21672870
# 21672871
# 21672872
# 21672873
# 21672874
# 21672875
# 21672876
# 21672877
# 21672878
# 21672879
# 21672880
# 21672881
# ...

# %% [markdown]
# Exercise 4: Deli
#
# Make a list called sandwich_orders and fill it with the names of various sandwiches. Then make an empty list called finished_sandwiches.
#
# Loop through the list of sandwich orders and print a message for each order, such as I made your tuna sandwich. As each sandwich is made,
#
# move it to the list of finished sandwiches. After all the sandwiches have been made, print a message listing each sandwich that was made.

# %%
sandwich_orders = ['dynamite chicken','kababb','cheese','fillet']
finished_sandwiches = []

while sandwich_orders:
  current_sandwich = sandwich_orders.pop()
  print("I made your " + current_sandwich + " sandwich.")
  finished_sandwiches.append(current_sandwich)

print("\n")
print('Sandwich Oders:')
for sandwich in finished_sandwiches:
  print(sandwich,'Sandwich')
# Out:
# I made your fillet sandwich.
# I made your cheese sandwich.
# I made your kababb sandwich.
# I made your dynamite chicken sandwich.
#
#
# Sandwich Oders:
# fillet Sandwich
# cheese Sandwich
# kababb Sandwich
# dynamite chicken Sandwich

# %% [markdown]
# Exercise 5: No Pastrami
#
# Using the list sandwich_orders from Exercise 7-8, make sure the sandwich 'pastrami' appears in the list at least three times. Add code
#
# near the beginning of your program to print a message saying the deli has run out of pastrami, and then use a while loop to remove all
#
# occurrences of 'pastrami' from sandwich_orders. Make sure no pastrami sandwiches end up in finished_sandwiches.

# %%
sandwich_orders = [
'dynamite', 'fillet', 'cheese', 'pastrami',
    'turkey', 'pastrami', 'kababb']
finished_sandwiches = []
#unfortnetly, there is no pastrami today
print("I'm sorry, we're all out of pastrami today.")
while 'pastrami' in sandwich_orders:
    sandwich_orders.remove('pastrami')
# use the while code for the order of the sandwich
print("\n")
while sandwich_orders:
    current_sandwich = sandwich_orders.pop()
    print(f"I'm working on your {current_sandwich} sandwich.")
    finished_sandwiches.append(current_sandwich)

print("\n")
for sandwich in finished_sandwiches:
    print(f"I made a {sandwich} sandwich.")
# Out:
# I'm sorry, we're all out of pastrami today.
#
#
# I'm working on your kababb sandwich.
# I'm working on your turkey sandwich.
# I'm working on your cheese sandwich.
# I'm working on your fillet sandwich.
# I'm working on your dynamite sandwich.
#
#
# I made a kababb sandwich.
# I made a turkey sandwich.
# I made a cheese sandwich.
# I made a fillet sandwich.
# I made a dynamite sandwich.
